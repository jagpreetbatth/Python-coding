# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Master Path

path = r'/Users/jagpreetbatth/Desktop/Career Foundry/Python/11-2021 Instacart Basket Analysis'

# %%
# Verify Path

path
# Out:
# '/Users/jagpreetbatth/Desktop/Career Foundry/Python/11-2021 Instacart Basket Analysis'

# %%
# Import orders_products_merged

ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'ords_prods_added_columns.pkl'))

# %%
# Create subset 

df = ords_prods_merge[:1000000]

# %%
# Check shape

df.shape
# Out:
# (1000000, 18)

# %%
# Verify Correct Import

df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795      1.0           2.0                 3.0                7.0
# 1   2398795      1.0           2.0                 3.0                7.0
# 2   2398795      1.0           2.0                 3.0                7.0
# 3   2398795      1.0           2.0                 3.0                7.0
# 4   2398795      1.0           2.0                 3.0                7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0       196.0                1.0        1.0
# 1                    15.0     10258.0                2.0        0.0
# 2                    15.0     12427.0                3.0        1.0
# 3                    15.0     13176.0                4.0        0.0
# 4                    15.0     26088.0                5.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# # Practice groupby() function

# %%
# Group by product_name

df.groupby('product_name')

# %%
# Use aggregate function to find mean

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.963494
# 2.0              18.294717
# 3.0              19.191348
# 4.0              18.995639
# 5.0              16.203058
# 6.0              16.552694
# 7.0              18.921518
# 8.0              17.305242
# 9.0              17.154301
# 10.0             21.232580
# 11.0             17.608736
# 12.0             16.733622
# 13.0             17.636887
# 14.0             18.723295
# 15.0             17.119301
# 16.0             19.091822
# 17.0             17.441581
# 18.0             20.627328
# 19.0             18.855026
# 20.0             18.414307
# 21.0             22.487622

# %%
# Alternative to agg() function using mean()

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     15.963494
# 2.0     18.294717
# 3.0     19.191348
# 4.0     18.995639
# 5.0     16.203058
# 6.0     16.552694
# 7.0     18.921518
# 8.0     17.305242
# 9.0     17.154301
# 10.0    21.232580
# 11.0    17.608736
# 12.0    16.733622
# 13.0    17.636887
# 14.0    18.723295
# 15.0    17.119301
# 16.0    19.091822
# 17.0    17.441581
# 18.0    20.627328
# 19.0    18.855026
# 20.0    18.414307
# 21.0    22.487622
# Name: order_number, dtype: float64

# %%
# Performing multiple aggregations (mean, min, max)

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean  min   max
# department_id
# 1.0              15.963494  2.0  99.0
# 2.0              18.294717  2.0  98.0
# 3.0              19.191348  2.0  99.0
# 4.0              18.995639  2.0  99.0
# 5.0              16.203058  2.0  99.0
# 6.0              16.552694  2.0  99.0
# 7.0              18.921518  2.0  99.0
# 8.0              17.305242  2.0  91.0
# 9.0              17.154301  2.0  99.0
# 10.0             21.232580  2.0  99.0
# 11.0             17.608736  2.0  99.0
# 12.0             16.733622  2.0  99.0
# 13.0             17.636887  2.0  99.0
# 14.0             18.723295  2.0  99.0
# 15.0             17.119301  2.0  99.0
# 16.0             19.091822  2.0  99.0
# 17.0             17.441581  2.0  99.0
# 18.0             20.627328  2.0  99.0
# 19.0             18.855026  2.0  99.0
# 20.0             18.414307  2.0  99.0
# 21.0             22.487622  2.0  97.0

# %%
# Create max_order column based on user_id and order_number

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Verify Column Creation

ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2398795      1.0           2.0                 3.0                7.0
# 1    2398795      1.0           2.0                 3.0                7.0
# 2    2398795      1.0           2.0                 3.0                7.0
# 3    2398795      1.0           2.0                 3.0                7.0
# 4    2398795      1.0           2.0                 3.0                7.0
# ..       ...      ...           ...                 ...                ...
# 95   1199898      2.0           6.0                 2.0                9.0
# 96   1199898      2.0           6.0                 2.0                9.0
# 97   1199898      2.0           6.0                 2.0                9.0
# 98   1199898      2.0           6.0                 2.0                9.0
# 99   1199898      2.0           6.0                 2.0                9.0
#
# ...

# %%
# Code to remove max on rows displayed

pd.options.display.max_rows = None

# %%
# Try head(100) again to see all 100 rows

ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2398795      1.0           2.0                 3.0                7.0
# 1    2398795      1.0           2.0                 3.0                7.0
# 2    2398795      1.0           2.0                 3.0                7.0
# 3    2398795      1.0           2.0                 3.0                7.0
# 4    2398795      1.0           2.0                 3.0                7.0
# 5    2398795      1.0           2.0                 3.0                7.0
# 6     473747      1.0           3.0                 3.0               12.0
# 7     473747      1.0           3.0                 3.0               12.0
# 8     473747      1.0           3.0                 3.0               12.0
# 9     473747      1.0           3.0                 3.0               12.0
# 10    473747      1.0           3.0                 3.0               12.0
# ...

# %%
# Derive columns with loc()

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Verify frequency of your new “loyalty_flag” column

ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15518037
# Loyal customer      10481046
# New customer         4564083
# NaN                  2078102
# Name: loyalty_flag, dtype: int64

# %%
# Verify Column Creation

ords_prods_merge[['user_id', 'loyalty_flag', 'max_order']].head(60)
# Out:
#     user_id      loyalty_flag  max_order
# 0       1.0  Regular customer       11.0
# 1       1.0  Regular customer       11.0
# 2       1.0  Regular customer       11.0
# 3       1.0  Regular customer       11.0
# 4       1.0  Regular customer       11.0
# 5       1.0  Regular customer       11.0
# 6       1.0  Regular customer       11.0
# 7       1.0  Regular customer       11.0
# 8       1.0  Regular customer       11.0
# 9       1.0  Regular customer       11.0
# 10      1.0  Regular customer       11.0
# 11      1.0  Regular customer       11.0
# 12      1.0  Regular customer       11.0
# 13      1.0  Regular customer       11.0
# 14      1.0  Regular customer       11.0
# 15      1.0  Regular customer       11.0
# 16      1.0  Regular customer       11.0
# 17      1.0  Regular customer       11.0
# 18      1.0  Regular customer       11.0
# 19      1.0  Regular customer       11.0
# 20      1.0  Regular customer       11.0
# 21      1.0  Regular customer       11.0
# ...

# %%
# Verify Changes

ords_prods_merge.shape
# Out:
# (32641268, 20)
