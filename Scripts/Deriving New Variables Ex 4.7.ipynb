# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Master Path

path = r'/Users/jagpreetbatth/Desktop/Career Foundry/Python/11-2021 Instacart Basket Analysis'

# %%
# Verify Path

path
# Out:
# '/Users/jagpreetbatth/Desktop/Career Foundry/Python/11-2021 Instacart Basket Analysis'

# %%
# Import orders_products_merged

df_ords_prods_merged = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Verify Correct Import

df_ords_prods_merged.shape
# Out:
# (32641268, 14)

# %% [markdown]
# ### Implementing a user-defined function in the Instacart project

# %%
# Create subset of df_ords_prods_merged (due to large data load)

df = df_ords_prods_merged[:1000000]

# %%
# Verify Correct Subset Defined

df.shape
# Out:
# (1000000, 14)

# %%
df
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 0        2398795      1.0           2.0                 3.0
# 1        2398795      1.0           2.0                 3.0
# 2        2398795      1.0           2.0                 3.0
# 3        2398795      1.0           2.0                 3.0
# 4        2398795      1.0           2.0                 3.0
# ...          ...      ...           ...                 ...
# 999995   1270896   6833.0           5.0                 2.0
# 999996   1270896   6833.0           5.0                 2.0
# 999997   1270896   6833.0           5.0                 2.0
# 999998   1270896   6833.0           5.0                 2.0
# 999999   1270896   6833.0           5.0                 2.0
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                     7.0                    15.0       196.0
# 1                     7.0                    15.0     10258.0
# ...

# %%
# Define Conditions based on Provided Price Ranges using if-else constructs

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Application of Function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/19/g__32h_54bjf6q9mxl_6vfjr0000gn/T/ipykernel_45562/380887843.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# Check values of newly created price label column

df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    667457
# Low-range product    312587
# High range            12209
# Not enough data        7747
# Name: price_range, dtype: int64

# %%
# Most expensive product within the subset

df['prices'].max()
# Out:
# 99999.0

# %%
# Define Conditions based on Provided Price Ranges using loc() Function

df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Check values of newly created price label column

df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     667457
# Low-range product     312587
# High-range product     12209
# NaN                     7747
# Name: price_range_loc, dtype: int64

# %%
# Use loc() function on entire dataframe to avoid memory overload faliure

df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Check values of newly created price label column for entire dataframe

df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# NaN                     236409
# Name: price_range_loc, dtype: int64

# %%
# Which day most orders take place - frequency of orders_day_of_the_week

df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    5827441
# 1.0    5339862
# 6.0    4224489
# 5.0    3983274
# 2.0    3976654
# 3.0    3628534
# 4.0    3582912
# NaN    2078102
# Name: orders_day_of_week, dtype: int64

# %%
# Create a for-loop to create a busiest day column

result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# Check Result

result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
# ...

# %%
# Merge result with ords_prods_merge

df_ords_prods_merged['busiest_day'] = result

# %%
# Check values of newly created busiest day column

df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    23230915
# Busiest day        5827441
# Least busy         3582912
# Name: busiest_day, dtype: int64

# %%
# Verify busiest day column creation

df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795      1.0           2.0                 3.0                7.0
# 1   2398795      1.0           2.0                 3.0                7.0
# 2   2398795      1.0           2.0                 3.0                7.0
# 3   2398795      1.0           2.0                 3.0                7.0
# 4   2398795      1.0           2.0                 3.0                7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0       196.0                1.0        1.0
# 1                    15.0     10258.0                2.0        0.0
# 2                    15.0     12427.0                3.0        1.0
# 3                    15.0     13176.0                4.0        0.0
# 4                    15.0     26088.0                5.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
# Create for-loop specifying busiest day(s)

result_two = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_two.append("Busiest days")
  elif value == 3 or value == 4:
    result_two.append("Least busy days")
  else:
    result_two.append("Regularly busy")

# %%
# Check Result_two

result_two
# Out:
# ['Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Least busy days',
# ...

# %%
# Create new column for busiest day(s)

df_ords_prods_merged['busiest_days'] = result_two

# %%
# Verify busiest day(s) column creation

df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795      1.0           2.0                 3.0                7.0
# 1   2398795      1.0           2.0                 3.0                7.0
# 2   2398795      1.0           2.0                 3.0                7.0
# 3   2398795      1.0           2.0                 3.0                7.0
# 4   2398795      1.0           2.0                 3.0                7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0       196.0                1.0        1.0
# 1                    15.0     10258.0                2.0        0.0
# 2                    15.0     12427.0                3.0        1.0
# 3                    15.0     13176.0                4.0        0.0
# 4                    15.0     26088.0                5.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
# Study Numbers for busiest and least busiest day(s) 0=SAT, 1=SUN, 2=MON, 3=TUE, 4=WED, 5=THU, 6=FRI

df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    5827441
# 1.0    5339862
# 6.0    4224489
# 5.0    3983274
# 2.0    3976654
# 3.0    3628534
# 4.0    3582912
# NaN    2078102
# Name: orders_day_of_week, dtype: int64

# %%
# Check values of newly created busiest day(s) column

df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy     14262519
# Busiest days       11167303
# Least busy days     7211446
# Name: busiest_days, dtype: int64

# %% [markdown]
# # Check for Accuracy of Results
# ## The count above shows these columns are accurate. Count for the least busy day(s) (3,4) is 3,628,534 + 3,582,912 which equals to 7,211,446 and count for the most busy day(s) (0,1) is 5,827,441 + 5,339,862  which equals 11,167,303.  This proves SAT and SUN are the BUSIEST DAYS and TUES and WED are the LEAST BUSIEST DAY(S).

# %%
# Busiest Hours of the Day

df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10.0    2612807
# 11.0    2583662
# 14.0    2537019
# 15.0    2507345
# 13.0    2506556
# 12.0    2464685
# 16.0    2383725
# 9.0     2328055
# NaN     2078102
# 17.0    1960305
# 8.0     1634048
# 18.0    1534215
# 19.0    1179165
# 20.0     917028
# 7.0      850713
# 21.0     751626
# 22.0     596846
# 23.0     378604
# 6.0      276824
# 0.0      205013
# 1.0      108995
# 5.0       83402
# 2.0       64486
# 4.0       49794
# 3.0       48248
# Name: order_hour_of_day, dtype: int64

# %%
# Create for-loop specifying busiest hours of the day

result_three = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value == 10 or value == 11 or value == 14 or value == 15 or value == 13 or value == 12 or value == 16 or value == 9 == 17 or value == 8 or value == 18 or value == 19:
    result_three.append("Most orders")
  elif value == 20 or value == 7 or value == 21 or value == 22 or value == 23 or value == 6 or value == 0 or value == 1:
    result_three.append("Average orders")
  else:
    result_three.append("Fewest orders")

# %%
# Check Result_three

result_three
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# New Column for Busiest hour of the day

# Create new column for busiest period of day
df_ords_prods_merged['busiest_period_of_day'] = result_three

# %%
# Verify Column Creation 

df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795      1.0           2.0                 3.0                7.0
# 1   2398795      1.0           2.0                 3.0                7.0
# 2   2398795      1.0           2.0                 3.0                7.0
# 3   2398795      1.0           2.0                 3.0                7.0
# 4   2398795      1.0           2.0                 3.0                7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0       196.0                1.0        1.0
# 1                    15.0     10258.0                2.0        0.0
# 2                    15.0     12427.0                3.0        1.0
# 3                    15.0     13176.0                4.0        0.0
# 4                    15.0     26088.0                5.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
# Frequency of new Column

df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21943227
# Fewest orders      6612392
# Average orders     4085649
# Name: busiest_period_of_day, dtype: int64

# %%
# Verify Correct Format and Dimension

df_ords_prods_merged.shape
# Out:
# (32641268, 18)

# %%
# Export dataframe as a pickle file into Prepared Data Folder

df_ords_prods_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'ords_prods_added_columns.pkl'))
