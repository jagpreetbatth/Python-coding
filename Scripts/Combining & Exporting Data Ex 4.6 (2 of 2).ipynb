# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Master Path

path = r'/Users/jagpreetbatth/Desktop/Career Foundry/Python/11-2021 Instacart Basket Analysis'

# %%
# Check Path

path
# Out:
# '/Users/jagpreetbatth/Desktop/Career Foundry/Python/11-2021 Instacart Basket Analysis'

# %%
# Import orders_products_combined Data Set in Pickle format

df_orders_products_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Ensure Correct Import

df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0         1.0   2398795      1.0           2.0                 3.0
# 1         1.0   2398795      1.0           2.0                 3.0
# 2         1.0   2398795      1.0           2.0                 3.0
# 3         1.0   2398795      1.0           2.0                 3.0
# 4         1.0   2398795      1.0           2.0                 3.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                7.0                    15.0       196.0                1.0
# 1                7.0                    15.0     10258.0                2.0
# 2                7.0                    15.0     12427.0                3.0
# 3                7.0                    15.0     13176.0                4.0
# 4                7.0                    15.0     26088.0                5.0
#
#    reordered _merge
# 0        1.0   both
# 1        0.0   both
# 2        1.0   both
# ...

# %%
# Check shape of Imported Data

df_orders_products_combined.shape
# Out:
# (32640698, 11)

# %%
# Import cleaned, wrangled, deduped product data set

df_product = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Ensure Correct Import

df_product.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Check shape of Imported Data

df_product.shape
# Out:
# (49672, 6)

# %%
# Drop Unnamed:0 Column - Not needed

df_products = df_product.drop(columns = ['Unnamed: 0',])

# %%
# Check to ensure DROP was made

df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Drop un-needed columns

df_orders_products_combined_1 = df_orders_products_combined.drop(columns = ['_merge','Unnamed: 0'])

# %%
# Check to ensure DROP was made

df_orders_products_combined_1.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795      1.0           2.0                 3.0                7.0
# 1   2398795      1.0           2.0                 3.0                7.0
# 2   2398795      1.0           2.0                 3.0                7.0
# 3   2398795      1.0           2.0                 3.0                7.0
# 4   2398795      1.0           2.0                 3.0                7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                    15.0       196.0                1.0        1.0
# 1                    15.0     10258.0                2.0        0.0
# 2                    15.0     12427.0                3.0        1.0
# 3                    15.0     13176.0                4.0        0.0
# 4                    15.0     26088.0                5.0        1.0

# %%
# Check Shape again

df_orders_products_combined_1.shape
# Out:
# (32640698, 9)

# %%
# Merge Data sets

orders_products_merged = df_orders_products_combined_1.merge(df_products, on = ['product_id'], how = 'left',indicator = True)

# %%
# Check for proper Merger

orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795      1.0           2.0                 3.0                7.0
# 1   2398795      1.0           2.0                 3.0                7.0
# 2   2398795      1.0           2.0                 3.0                7.0
# 3   2398795      1.0           2.0                 3.0                7.0
# 4   2398795      1.0           2.0                 3.0                7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0       196.0                1.0        1.0
# 1                    15.0     10258.0                2.0        0.0
# 2                    15.0     12427.0                3.0        1.0
# 3                    15.0     13176.0                4.0        0.0
# 4                    15.0     26088.0                5.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge
# ...

# %%
# Confrim with Merger Flags

orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only       236409
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export using pickle format (due to large size of combined data frame)

orders_products_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged.pkl'))
